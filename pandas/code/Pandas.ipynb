# %% [markdown]
# ### <center><h2> INGENIERÍA EN BIOTECNOLOGÍA</h2></center>
# # <center><h1 style="color:red">GBI6 - BIOINFORMÁTICA</h1></center>
#
# <img src="https://www.ikiam.edu.ec/wp-content/uploads/2021/12/logo-ikiam-1.png" width=400 height=300 />
#
# # PANDAS

# %% [markdown]
# Este contenido se basa en la demosración de [10 Minutes Introduction](http://pandas.pydata.org/pandas-docs/stable/10min.html), y el tutorial de [pandas tutorials](http://pandas.pydata.org/pandas-docs/stable/tutorials.html).
#
# Se puede revisar algunas formas rápidas de trabajar en Jupyrer en: [Jupyter keyboard shortcuts](https://www.cheatography.com/weidadeyue/cheat-sheets/jupyter-notebook/).

# %% [markdown]
# # Librerías

# %%
# this will enable some additional autocompletion using the tab button

# %config IPCompleter.greedy=True

# %%
#!pip install pandas

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt # graficos 
import seaborn as sns # estadistica y visualizacion
#!pip install pandas

# %% [markdown]
# # Crear series de datos y mostrar

# %% [markdown]
# Crea una lista de nombre ```lista``` y luego convierte a un objeto de tipo Serie de nombre ```s```. Imprime su contenido.
#
# | S   |
# |-----|
# | 1.0 |
# | 1.5 |
# | 3.0 |
# | 4.3 |
# | 8.2 |

# %%
lista = [1, 1.5, 3, 4.3, 8.2, 1, 3, 3]
lista
# Out:
# [1, 1.5, 3, 4.3, 8.2, 1, 3, 3]

# %%
df1 = pd.DataFrame(lista)
df1.columns = ["frutas"]
df1
# Out:
#    frutas
# 0     1.0
# 1     1.5
# 2     3.0
# 3     4.3
# 4     8.2
# 5     1.0
# 6     3.0
# 7     3.0

# %%
rnames = ["lunes", "martes", "miercoles", "jueves", "viernes", "sabado", "domingo", "otro"]
cnames = ["long_pata"]
df1 = pd.DataFrame(lista, rnames, cnames)
df1
# Out:
#            long_pata
# lunes            1.0
# martes           1.5
# miercoles        3.0
# jueves           4.3
# viernes          8.2
# sabado           1.0
# domingo          3.0
# otro             3.0

# %%
nombres = ["Kim", "Henry"]
talla = [36, 40]
genero = ["F", "M"]
ciudad = ["Quito", "Riobamba"]
df10 = pd.DataFrame(talla)
df10.columns = ["talla"]
df10
# Out:
#    talla
# 0     36
# 1     40

# %%
df11 = pd.DataFrame(talla, nombres, ["talla"])
df11
# Out:
#        talla
# Kim       36
# Henry     40

# %%
dfgbi6 = pd.DataFrame({'Nombre' : nombres,
              'Talla' : talla,
              'Genero' : genero},
              index = ciudad)

# %%
df1.mean()
# Out:
# long_pata    3.125
# dtype: float64

# %%
df = sns.load_dataset('iris')
df.tail(2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#df.mean()

# %%
df["petal_length"].std()
# Out:
# 1.7652982332594662

# %%
df["sepal_width"].mean()
# Out:
# 3.0573333333333337

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dfgbi6.describe()
# Out:
#            Talla
# count   2.000000
# mean   38.000000
# std     2.828427
# min    36.000000
# 25%    37.000000
# 50%    38.000000
# 75%    39.000000
# max    40.000000

# %% [markdown]
# # Crea un DataFrame con valores en filas y columnas

# %% [markdown]
# Crea un dataframe con la información que se muestra en la siguiente tabla.
#
# |index   |a |b  |c   |d           |e |
# |--------|--|---|----|------------|--|
# |1       |2 |3  |5.  |caballo     |13|
# |2       |3 |1  |1.4 |gato        |11|
# |3       |4 |9  |1.2 |perro       |  |
# |4       |5 |12 |0.8 |tortuga     |  |
# |5       |6 |2  |2.3 |conejoo     |9 |
#
# Luego realiza lo siguiente
# * Accede a los valores de alguna fila
# * Accede a los valores de alguna(s) celda(s)
# * Imprime los índices
# * Imprime los nombres de columna
# * Accede a los valores de una columna
# * Renombra alguna columna
# * Extrae y guarda la información en un nuevo dataframe
# * Obten una descripción y las estadísticas elementales del dataframe

# %%
# Crear la data
df2 = pd.DataFrame({'ancho' : [2,3,4,5,6],
                    'largo' : [3,1,9,12,2],
                    'profundidad' : [5.0, 7.4, 4.2, 10.8, 2.3],
                    'animal' : pd.Categorical(['caballo', 'gato', 'perro', 'tortuga', 'conejo']),
                    'edad' : [13, 11, None, None, 9]}, 
                    index=["Loja", "Lago", "Coca", "Puyo", "Manta"])
df2
# Out:
#        ancho  largo  profundidad   animal  edad
# Loja       2      3          5.0  caballo  13.0
# Lago       3      1          7.4     gato  11.0
# Coca       4      9          4.2    perro   NaN
# Puyo       5     12         10.8  tortuga   NaN
# Manta      6      2          2.3   conejo   9.0

# %%
a = [2,3,4,5,6]
b = [3,1,9,12,2],
c = [5.0, 7.4, 4.2, 10.8, 2.3],
d = pd.Categorical(['caballo', 'gato', 'perro', 'tortuga', 'conejo']),
e = [13, 11, None, None, 9], 
index=["a", "b", "c", "d", "e"]

# %%
for i in range(5):
    a = "Hola" + str(i)
    print(i+1, a)
# Out:
# 1 Hola0
# 2 Hola1
# 3 Hola2
# 4 Hola3
# 5 Hola4

# %%
df2["c"].std()
# Out:
# 3.2753625753494835

# %%
df2.describe()
# Out:
#               a          b          c     e
# count  5.000000   5.000000   5.000000   3.0
# mean   4.000000   5.400000   5.940000  11.0
# std    1.581139   4.827007   3.275363   2.0
# min    2.000000   1.000000   2.300000   9.0
# 25%    3.000000   2.000000   4.200000  10.0
# 50%    4.000000   3.000000   5.000000  11.0
# 75%    5.000000   9.000000   7.400000  12.0
# max    6.000000  12.000000  10.800000  13.0

# %% [markdown]
# Para leer cada fila, se utiliza el comando ```iloc``` que itera desde el valor ```0``` hasta el último valor de fila.
#
# Para agregar el identificador de columna, se puede utilizar el comando ```loc``` que acepta identificadores.

# %%
df2
# Out:
#        ancho  largo  profundidad   animal  edad
# Loja       2      3          5.0  caballo  13.0
# Lago       3      1          7.4     gato  11.0
# Coca       4      9          4.2    perro   NaN
# Puyo       5     12         10.8  tortuga   NaN
# Manta      6      2          2.3   conejo   9.0

# %%
df2.iloc[1:4,1:4]
# Out:
#       largo  profundidad   animal
# Lago      1          7.4     gato
# Coca      9          4.2    perro
# Puyo     12         10.8  tortuga

# %%
df2.iloc[2:,:2]
# Out:
#        ancho  largo
# Coca       4      9
# Puyo       5     12
# Manta      6      2

# %%
#df2.loc[2,'d']

# %%
# Todas las filas 
for i in range(0, len(df2)):
    print(df2.iloc[i, :])
# Out:
# a          2
# b          3
# c        5.0
# d    caballo
# e       13.0
# Name: a, dtype: object
# a       3
# b       1
# c     7.4
# d    gato
# e    11.0
# Name: b, dtype: object
# a        4
# b        9
# c      4.2
# d    perro
# e      NaN
# Name: c, dtype: object
# a          5
# b         12
# c       10.8
# d    tortuga
# e        NaN
# Name: d, dtype: object
# a         6
# b         2
# c       2.3
# d    conejo
# e       9.0
# Name: e, dtype: object

# %%
# Todas las columnas
for i in range(0, len(df2.columns)):
    print(df2.iloc[:,i].count())
# Out:
# 5
# 5
# 5
# 5
# 3

# %%
# Indices de fila y nombres de columna
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=150, step=1)
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['ancho', 'largo', 'profundidad', 'animal', 'edad'], dtype='object')

# %%
df2.index
# Out:
# Index(['Loja', 'Lago', 'Coca', 'Puyo', 'Manta'], dtype='object')

# %%
df2.loc["Lago":"Puyo", "largo":"animal"]
# Out:
#       largo  profundidad   animal
# Lago      1          7.4     gato
# Coca      9          4.2    perro
# Puyo     12         10.8  tortuga

# %%
# Utilizar nombre de columna para acceder a la data
print(df.loc[0:3,'petal_length'])
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# Name: petal_length, dtype: float64

# %%
# Renombrar columnas
df2.columns = ['longitud', 'ancho', 'masa', 'nombre_comun', 'observaciones']
df2.index = ["Quito", "Tena", "Cayambe", "Tabacundo", "Cuenca"]
print(df2.columns.tolist()[:])
print(df2)
# Out:
# ['longitud', 'ancho', 'masa', 'nombre_comun', 'observaciones']
#            longitud  ancho  masa nombre_comun  observaciones
# Quito             2      3   5.0      caballo           13.0
# Tena              3      1   7.4         gato           11.0
# Cayambe           4      9   4.2        perro            NaN
# Tabacundo         5     12  10.8      tortuga            NaN
# Cuenca            6      2   2.3       conejo            9.0

# %%
df2
# Out:
#            longitud  ancho  masa nombre_comun  observaciones
# Quito             2      3   5.0      caballo           13.0
# Tena              3      1   7.4         gato           11.0
# Cayambe           4      9   4.2        perro            NaN
# Tabacundo         5     12  10.8      tortuga            NaN
# Cuenca            6      2   2.3       conejo            9.0

# %%
# Extraer una seccion de la data y guardar en una nueva dataframe
df_3 = df2.iloc[2:5, 1:4]
print(df_3)
# Out:
#            ancho  masa nombre_comun
# Cayambe        9   4.2        perro
# Tabacundo     12  10.8      tortuga
# Cuenca         2   2.3       conejo

# %%
# Resumen de datos
df2.describe(percentiles=None, include=None, exclude=None)
# Out:
#        longitud      ancho       masa  observaciones
# count  5.000000   5.000000   5.000000            3.0
# mean   4.000000   5.400000   5.940000           11.0
# std    1.581139   4.827007   3.275363            2.0
# min    2.000000   1.000000   2.300000            9.0
# 25%    3.000000   2.000000   4.200000           10.0
# 50%    4.000000   3.000000   5.000000           11.0
# 75%    5.000000   9.000000   7.400000           12.0
# max    6.000000  12.000000  10.800000           13.0

# %% [markdown]
# # Guardar la información

# %% [markdown]
# Para exportar se utiliza el comando ```nombredataframe.to_csv()```. Se tiene varios criterios que se pueden definir.

# %%
df2.to

# %%
df2.to_csv('animales.csv', header=True, index=True, sep='\t', mode='w')

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.8/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import openpyxl
df2.to_excel("../data/animales.xlsx", header=True, index=False)

# %% [markdown]
# # Data Import

# %% [markdown]
# Importar la información de ```data.csv``` en un dataframe de nombre _df2_:

# %%
pd.read_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 pd.read
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
cancer = pd.read_csv('../data/cancerdata.csv', header=0, sep=',')
cancer.shape
# Out:
# (569, 33)

# %%
cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
cancer_stat = cancer.describe()
cancer_stat.to_excel("../data/stats_cancer.xlsx")

# %%
cancer_stat.to_latex("data.tex")

# %% [markdown]
# Importar la misma data ahora a un archivo _df3_:

# %%
df3 = pd.read_csv('../data/data.csv', header=0, sep=';')
print(df3)
# Out:
#    Unnamed: 0  longitud  ancho  masa nombre_comun  observaciones
# 0           1         2      3   5.0      caballo           13.0
# 1           2         3      1   1.4         gato           11.0
# 2           3         4      9   1.2        perro            NaN
# 3           4         5     12   0.8      tortuga            NaN
# 4           5         6      2   2.3       conejo            9.0

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/python/3.10.8/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
import openpyxl
dengue = pd.read_excel("../data/dengue.xlsx")
dengue.to_csv("dengue.csv", header=True, index=False, sep=';', mode='w')

# %% [markdown]
# # Filtrado de datos en un DataFrame
# Usando la data de _df2_:
#
# * Seleccione los valore de la 3er columna que son mayores que 2
# * select rows that contain values greater than 2 in the 3rd column or 'cat' in the 4th column
# * drop rows with missing data
# * drop duplicate rows
# * drop 1st column from dataframe
# * sort rows by 2nd column
# * convert Strings in 4th column to title-case

# %%
cancer.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
#
# [2 rows x 33 columns]

# %%
cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
dengue.columns
# Out:
# Index(['Provincia', 'Estancia', 'Causa'], dtype='object')

# %%
cancer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cancer
#
# NameError: name 'cancer' is not defined

# %%
cancer["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
cancerM = cancer[cancer["diagnosis"]=="M"]
cancerM.shape
# Out:
# (212, 33)

# %%
cancerM[cancerM["radius_mean"] < 15
].shape
# Out:
# (51, 33)

# %%
dengue["Provincia"].unique()
# Out:
# array(['EL ORO', 'GUAYAS', 'MANABI'], dtype=object)

# %%
cancerB10 = cancer[(cancer["diagnosis"]=="B") &  (cancer["radius_mean"] >12) &(cancer["radius_mean"] < 16)]
stats_cancerb10 = cancerB10.describe()
cancerB10.shape
# Out:
# (186, 33)

# %%
# select rows containing values greater than 2 in the 3rd column
# loc[df2['c'] returns series of true and false values which rows to take and which not
df2.loc[df2['masa'] > 2]
# Out:
#    Unnamed: 0  Unnamed: 0.1  longitud  ancho  masa nombre_comun  observaciones
# 0           0             1         2      3   5.0      caballo           13.0
# 4           4             5         6      2   2.3       conejo            9.0

# %%
df3.loc[df3["nombre_comun"] == "conejo"]
# Out:
#    Unnamed: 0  longitud  ancho  masa nombre_comun  observaciones
# 4           5         6      2   2.3       conejo            9.0

# %%
# select rows that contain values greater than 2 in the 3rd column or 'cat' in the 4th column
df2.loc[(df2['masa'] > 2) & (df2['nombre_comun'] == 'gato')]
# Out:
#     longitud  ancho  masa nombre_comun  observaciones
# a2         3      1   7.4         gato           11.0

# %%
df5 = pd.read_csv("../data/iris.csv")
df5
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df5.loc[df5["Species"] == "Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %%
df5.loc[(df5["Species"] == "Iris-setosa") & (df5["PetalLengthCm"] >= 1.7)]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa

# %%
iris_sub = df5.loc[(df5["Species"] == "Iris-setosa") & (df5["PetalLengthCm"] >= 1.7)]
iris_sub["SepalWidthCm"].mean()
# Out:
# 3.5999999999999996

# %%
iris_sub.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   6.000000       6.000000      6.000000       6.000000      6.000000
# mean   23.333333       5.250000      3.600000       1.766667      0.333333
# std    12.628011       0.314643      0.260768       0.103280      0.121106
# min     6.000000       4.800000      3.300000       1.700000      0.200000
# 25%    19.500000       5.100000      3.400000       1.700000      0.225000
# 50%    22.500000       5.250000      3.600000       1.700000      0.350000
# 75%    24.750000       5.400000      3.800000       1.850000      0.400000
# max    45.000000       5.700000      3.900000       1.900000      0.500000

# %%
df2.loc[(df2['masa'] > 0.1) & (df2['nombre_comun'] == 'gato')]
# Out:
#    Unnamed: 0  longitud  ancho  masa nombre_comun  observaciones
# 1           2         3      1   1.4         gato           11.0

# %%
df2
# Out:
#     longitud  ancho  masa nombre_comun  observaciones
# a1         2      3   5.0      caballo           13.0
# a2         3      1   7.4         gato           11.0
# b1         4      9   4.2        perro            NaN
# b2         5     12  10.8      tortuga            NaN
# c1         6      2   2.3       conejo            9.0

# %%
# drop rows with missing data
print(df2)
df2.dropna()
# Out:
#    longitud  ancho  masa nombre_comun  observaciones
# 1         2      3   5.0      caballo           13.0
# 2         3      1   1.4         gato           11.0
# 3         4      9   1.2        perro            NaN
# 4         5     12   0.8      tortuga            NaN
# 5         6      2   2.3       conejo            9.0
#    longitud  ancho  masa nombre_comun  observaciones
# 1         2      3   5.0      caballo           13.0
# 2         3      1   1.4         gato           11.0
# 5         6      2   2.3       conejo            9.0

# %%
# drop duplicate rows
df2.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
#    Unnamed: 0  Unnamed: 0.1  longitud  ancho  masa nombre_comun  observaciones
# 0           0             1         2      3   5.0      caballo           13.0
# 1           1             2         3      1   1.4         gato           11.0
# 2           2             3         4      9   1.2        perro            NaN
# 3           3             4         5     12   0.8      tortuga            NaN
# 4           4             5         6      2   2.3       conejo            9.0

# %%
# drop 1st column from dataframe
df2.drop(df2.index[0])
# Out:
#    Unnamed: 0  Unnamed: 0.1  longitud  ancho  masa nombre_comun  observaciones
# 2           2             3         4      9   1.2        perro            NaN
# 3           3             4         5     12   0.8      tortuga            NaN
# 4           4             5         6      2   2.3       conejo            9.0

# %%
# sort rows by 2nd column
df2.sort_values(by=['ancho'])
# Out:
#    Unnamed: 0  Unnamed: 0.1  longitud  ancho  masa nombre_comun  observaciones
# 1           1             2         3      1   1.4         gato           11.0
# 4           4             5         6      2   2.3       conejo            9.0
# 0           0             1         2      3   5.0      caballo           13.0
# 2           2             3         4      9   1.2        perro            NaN
# 3           3             4         5     12   0.8      tortuga            NaN

# %%
df5.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df5.sort_values(by=['PetalLengthCm', 'SepalLengthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 22    23            4.6           3.6            1.0           0.2
# 13    14            4.3           3.0            1.1           0.1
# 35    36            5.0           3.2            1.2           0.2
# 14    15            5.8           4.0            1.2           0.2
# 38    39            4.4           3.0            1.3           0.2
# ..   ...            ...           ...            ...           ...
# 131  132            7.9           3.8            6.4           2.0
# 105  106            7.6           3.0            6.6           2.1
# 117  118            7.7           3.8            6.7           2.2
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
#
#             Species
# 22      Iris-setosa
# 13      Iris-setosa
# 35      Iris-setosa
# 14      Iris-setosa
# 38      Iris-setosa
# ..              ...
# 131  Iris-virginica
# 105  Iris-virginica
# 117  Iris-virginica
# 122  Iris-virginica
# 118  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# convert Strings in 4th column to title-case
df2['nombre_comun'].str.upper()
# Out:
# 0    CABALLO
# 1       GATO
# 2      PERRO
# 3    TORTUGA
# 4     CONEJO
# Name: nombre_comun, dtype: object

# %% [markdown]
# # Agregación de información a un DataFrame

# %%
df4 = pd.read_csv('df4.csv')
print(df4)
# Out:
#     familia  masa nombre_comun  observaciones
# 0  mamifero   5.0      caballo           13.0
# 1  mamifero   1.4         gato           11.0
# 2  mamifero   1.2        perro            NaN
# 3       pez   0.1       pirana            NaN
# 4    reptil   2.3    serpiente            9.0
# 5       pez   1.8      tilapia           10.0
# 6       pez   0.8        carpa            NaN

# %%
cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
cancer_subset = cancer.iloc[:, 1:5]
cancer_subset.head(2)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean
# 0         M        17.99         10.38           122.8
# 1         M        20.57         17.77           132.9

# %%
cmean = cancer_subset.groupby('diagnosis').mean()
cstd = cancer_subset.groupby('diagnosis').std()
cstd
# Out:
#            radius_mean  texture_mean  perimeter_mean
# diagnosis
# B             1.780512      3.995125       11.807438
# M             3.203971      3.779470       21.854653

# %%
frames = [cmean,cstd]
c_mean_std = pd.concat(frames)
c_mean_std.to_excel("../data/cancertype.xlsx")

# %%
# Agregación de valores
df4.groupby('familia').mean().reset_index()
# Out:
#     familia      masa  observaciones
# 0  mamifero  2.533333           12.0
# 1       pez  0.900000           10.0
# 2    reptil  2.300000            9.0

# %%
dengue.columns
# Out:
# Index(['Provincia', 'Estancia', 'Causa'], dtype='object')

# %%
dengue.groupby('Provincia').mean("Estancia").reset_index()
# Out:
#   Provincia  Estancia
# 0    EL ORO  3.080139
# 1    GUAYAS  4.000816
# 2    MANABI  3.290780

# %% [markdown]
# # Union de datos

# %% [markdown]
# * Merge df3 with df4 on columns c, d and e. Change columns with same names in a meaningful way.

# %% [markdown]
# * Now perform a full outer join of the data, to keep all rows contained in either of the two dataframes.

# %%
# Merge df3 with df4 inner join
pd.merge(df2, df4, on=['masa', 'nombre_comun', 'observaciones'], how='inner')
# Out:
#    Unnamed: 0  longitud  ancho  masa nombre_comun  observaciones   familia
# 0           1         2      3   5.0      caballo           13.0  mamifero
# 1           2         3      1   1.4         gato           11.0  mamifero
# 2           3         4      9   1.2        perro            NaN  mamifero

# %%
# Merge df3 with df4 outer join
pd.merge(df3, df4, on=['c', 'd', 'e'], how='outer')
# Out:
#     b_x    c         d     e      b_y
# 0   3.0  5.0     horse  13.0   mammal
# 1   1.0  1.4       cat  11.0   mammal
# 2   9.0  1.2       dog   NaN   mammal
# 3  12.0  0.8  tortoise   NaN      NaN
# 4   2.0  2.3    rabbit   9.0      NaN
# 5   NaN  0.1  goldfish   NaN     fish
# 6   NaN  2.3     snake   9.0  reptile
# 7   NaN  1.8       koi  10.0     fish
# 8   NaN  0.8      carp   NaN     fish
