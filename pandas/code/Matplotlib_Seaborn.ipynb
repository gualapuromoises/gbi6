# %% [markdown]
# # Visualización en Python

# %%
# for matplotlib to work smoothly with Jupyter notebooks the following "Magic" is required:
# %matplotlib inline

# %%
# librerias
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import math
import seaborn as sns
import pandas as pd

# %% [markdown]
# # Bases de Matplotlib
#
# Basado en el curso dictado por http://www.labri.fr/perso/nrougier/teaching/matplotlib/

# %% [markdown]
# ### Gráficos simples

# %% [markdown]
# - Crear un numpy array X con 256 valores entre -Pi y +Pi

# %%
# Creacion de datos ficticios
pi = math.pi
pi_minus = -math.pi
X = np.linspace(pi_minus, pi, num=256)

# %% [markdown]
# - Crear dos arrays Coseno,Seno

# %%
# Seno y coseno
Coseno = np.cos(X)
Seno = np.sin(X)

# %% [markdown]
# - Graficar las curvas seno y coseno

# %%
# Curvas
plt.plot(X,Coseno)
plt.plot(X,Seno)

# %% [markdown]
# - Formatos

# %%
# Asignar características a las curvas
plt.plot(X,Coseno, linewidth=3, c="green", label = "Coseno") # grosor, color, leyenda
plt.plot(X,Seno, linewidth=3, c="black", label = "Seno")
plt.xlabel("Angulo $\mu$(rad)")  # Leyenda eje x
plt.ylabel("Función f($\mu$)") # Leyenda eje y
plt.title("Funciones trigonométricas") # Titulo de la gráfica
plt.legend() # Permite ver las leyendas
plt.show()

# %%
cancer = pd.read_csv('../data/cancerdata.csv', header=0, sep=',')
len(cancer.columns)
# Out:
# 33

# %%
plt.plot(cancer["radius_mean"], cancer["fractal_dimension_mean"], 'bo', 
        markersize = 0.7)
plt.show()

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ## Extracción de datos

# %% [markdown]
# Graficar múltiples curvas de disribución normal como se muestra en la sigueinte gráfica

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Normal_Distribution_PDF.svg/720px-Normal_Distribution_PDF.svg.png'>

# %%
# Parameters for normal distributions
import scipy.stats as stats
params = [(0,0.2,'blue'), (0, 1.0, 'red'), (0, 5.0, 'orange'), (-2,0.5,'green')]

for mean, variance, color in params:
    x = np.linspace(mean - 3*math.sqrt(variance), mean + 3*math.sqrt(variance), 100)
    sigma = math.sqrt(variance)
    label = '$\mu = %.1f, \ \sigma^2=%.1f$' %(mean, variance)
    y_norm = stats.norm.pdf(x, mean, sigma)
    plt.plot(x, y_norm, label=label, c = color)
plt.xlim(-5,5)
plt.ylim(0,1)
plt.xlabel('X')
plt.ylabel('$φ_{μ,σ^2}(X)$')
plt.title('Distribución Normal')
plt.legend(title = "Parámetros")
plt.show()

# %% [markdown]
# ## Visualización con Boxplots

# %%
experimento1 = np.random.normal(0, np.sqrt(0.2), 1000)
experimento2 = np.random.normal(0, np.sqrt(1.0), 1000)
experimento3 = np.random.normal(0, np.sqrt(5.0), 1000)
experimento4 = np.random.normal(-2, np.sqrt(0.5), 1000)

data = [experimento1, experimento2, experimento3, experimento4]

# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))  # valores en inch (pulgada)

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data)
plt.xlabel('Experimentos')
plt.ylabel('Distribución')
plt.title('Boxplots de distribuciones normales')
plt.show()

# %% [markdown]
# ## Histogramas

# %%
plt.title('Histogramas de las distribuciones normales')
plt.xlabel('Valores X', fontsize = 24, rotation = 90)
plt.ylabel('Frecuencia', fontsize = 24, rotation = 45)
plt.hist(data, bins=20)
nombres = ['Experimento 1', 'Experimento 2', 'Experimento 2', 'Experimento 4']
plt.legend(nombres, title = "EXPERIMENTOS")
plt.show()

# %% [markdown]
# ## Gráficos 3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.1)
Y = np.arange(-4, 4, 0.1)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
plt.xlabel('X')
plt.ylabel('Y', fontsize = 24, rotation = 45)
plt.title('Mapa de calor')
plt.show()
# Out:
# C:\Users\MoisesG\AppData\Local\Temp/ipykernel_17144/775058587.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# # Múltiples gráficos

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
y1 = np.sin(x ** 2)
y2 = x ** 2 +1
y3 = np.log(x ** 2)
y4 = np.sqrt(x + 2) + 4

fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y1)
axs[0, 0].set_title('$sin(x^2)$')
axs[0, 1].plot(x, y2, 'tab:orange')
axs[0, 1].set_title('$x^2+1$')
axs[1, 0].plot(x, y3, 'tab:green')
axs[1, 0].set_title('$ln(x^2)$')
axs[1, 1].plot(x, y4, 'tab:red')
axs[1, 1].set_title('$\sqrt{x+2}+4$')

for ax in axs.flat:
    ax.set(xlabel='x', ylabel='y')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
# Out:
# C:\Users\MoisesG\AppData\Local\Temp/ipykernel_18288/55984478.py:5: RuntimeWarning: invalid value encountered in sqrt
#   y4 = np.sqrt(x + 2) + 4

# %% [markdown]
# # Guardar gráficos

# %%
fig.savefig('graficos.eps', dpi = 300)

# %%
sns.barplot(x=['A','B','C'], y=[33,44,20])
# Out:
# <AxesSubplot:>

# %%
from sklearn import datasets
from sklearn.decomposition import PCA
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5

plt.figure(2, figsize=(8, 6))
plt.clf()
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1, edgecolor="k")
plt.xlabel("Sepal length")
plt.ylabel("Sepal width")

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
X_reduced = PCA(n_components=3).fit_transform(iris.data)
ax.scatter(
    X_reduced[:, 0],
    X_reduced[:, 1],
    X_reduced[:, 2],
    c=y,
    cmap=plt.cm.Set1,
    edgecolor="k",
    s=40,
)
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])

plt.show()
# Out:
# C:\Users\MoisesG\AppData\Local\Temp/ipykernel_14164/3347605397.py:21: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, elev=-150, azim=110)
